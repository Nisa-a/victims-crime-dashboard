# %% [markdown]
# <a href="https://colab.research.google.com/github/Nisa-a/victims-crime-dashboard/blob/main/cleaned_data_crime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/victims-of-crime-data.csv", encoding='latin-1')
df.head()
# Out:
#                                              Measure Ethnicity Ethnicity_type  \
# 0  Proportion of adults who were victims of all C...       All            All
# 1  Proportion of adults who were victims of all C...       All            All
# 2  Proportion of adults who were victims of all C...       All            All
# 3  Proportion of adults who were victims of all C...       All            All
# 4  Proportion of adults who were victims of all C...       All            All
#
#       Time          Time_type          Geography      Geography_type  \
# 0  2013/14  Year ending March  England and Wales  ONS geography code
# 1  2013/14  Year ending March  England and Wales  ONS geography code
# 2  2013/14  Year ending March  England and Wales  ONS geography code
# 3  2013/14  Year ending March  England and Wales  ONS geography code
# 4  2013/14  Year ending March  England and Wales  ONS geography code
#
#   Geography code Gender    Age Socio-economic classification Household income  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1183 entries, 0 to 1182
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Measure                        1183 non-null   object
#  1   Ethnicity                      1183 non-null   object
#  2   Ethnicity_type                 1183 non-null   object
#  3   Time                           1183 non-null   object
#  4   Time_type                      1183 non-null   object
#  5   Geography                      1183 non-null   object
#  6   Geography_type                 1183 non-null   object
#  7   Geography code                 1183 non-null   object
#  8   Gender                         1183 non-null   object
#  9   Age                            1183 non-null   object
#  10  Socio-economic classification  1183 non-null   object
#  11  Household income               1183 non-null   object
# ...

# %%
df.shape
# Out:
# (1183, 18)

# %%
df.describe()
# Out:
#                                                   Measure Ethnicity  \
# count                                                1183      1183
# unique                                                  1        30
# top     Proportion of adults who were victims of all C...     White
# freq                                                 1183       256
#
#          Ethnicity_type                          Time         Time_type  \
# count              1183                          1183              1183
# unique                4                             9                 2
# top     ONS 2011  5 + 1  2014/15, 2015/16 and 2016/17  3 years combined
# freq                750                           481               927
#
#                 Geography      Geography_type Geography code Gender   Age  \
# count                1183                1183           1183   1183  1183
# unique                 53                   1             52      4     8
# ...

# %%
df.describe(include='object')
# Out:
#                                                   Measure Ethnicity  \
# count                                                1183      1183
# unique                                                  1        30
# top     Proportion of adults who were victims of all C...     White
# freq                                                 1183       256
#
#          Ethnicity_type                          Time         Time_type  \
# count              1183                          1183              1183
# unique                4                             9                 2
# top     ONS 2011  5 + 1  2014/15, 2015/16 and 2016/17  3 years combined
# freq                750                           481               927
#
#                 Geography      Geography_type Geography code Gender   Age  \
# count                1183                1183           1183   1183  1183
# unique                 53                   1             52      4     8
# ...

# %%
df.isnull().sum()
# Out:
# Measure                          0
# Ethnicity                        0
# Ethnicity_type                   0
# Time                             0
# Time_type                        0
# Geography                        0
# Geography_type                   0
# Geography code                   0
# Gender                           0
# Age                              0
# Socio-economic classification    0
# Household income                 0
# Value                            0
# Value_type                       0
# Sample size                      0
# Standard Error                   0
# Lower CI                         0
# Upper CI                         0
# dtype: int64

# %%
df['Measure'].unique() #drop
# Out:
# array(['Proportion of adults who were victims of all CSEW crime (excluding fraud and computer misuse)'],
#       dtype=object)

# %%
df['Ethnicity'].unique()
# Out:
# array(['All', 'Asian', 'Black', 'White British', 'White Irish',
#        'Gypsy or Irish Traveller', 'Any other White background',
#        'Mixed White and Black Caribbean', 'Mixed White and Black African',
#        'Mixed White and Asian',
#        'Any other Mixed/Multiple ethnic background', 'Indian',
#        'Pakistani', 'Bangladeshi', 'Chinese',
#        'Any other Asian background', 'Black African', 'Black Caribbean',
#        'Any other Black background', 'Arab', 'Any other ethnic group',
#        'Mixed', 'Other ', 'White', 'Mixed/Multiple',
#        'Asian/Asian British', 'Black/African/Caribbean/Black British',
#        'Other', 'All other Ethnic groups', 'Gypsy or Irish traveller'],
#       dtype=object)

# %%
df['Ethnicity_type'].unique() #drop
# Out:
# array(['All', 'ONS 2011  5 + 1', 'ONS 2011 18 + 1', 'White & Other'],
#       dtype=object)

# %%
df['Time'].unique() #filter for only single years.
# Out:
# array(['2013/14', '2014/15', '2014/15, 2015/16 and 2016/17', '2015/16',
#        '2016/17', '2017/18', '2017/18, 2018/19 and 2019/20', '2018/19',
#        '2019/20'], dtype=object)

# %%
df['Time_type'].unique() #drop
# Out:
# array(['Year ending March', '3 years combined'], dtype=object)

# %%
df['Geography'].unique()
# Out:
# array(['England and Wales', 'North East', 'Cleveland', 'Durham',
#        'Northumbria', 'North West', 'Cheshire', 'Cumbria',
#        'Greater Manchester', 'Lancashire', 'Merseyside',
#        'Yorkshire and the Humber', 'Humberside', 'North Yorkshire',
#        'South Yorkshire', 'West Yorkshire', 'East Midlands', 'Derbyshire',
#        'Leicestershire', 'Lincolnshire', 'Northamptonshire',
#        'Nottinghamshire', 'West Midlands Region', 'Staffordshire',
#        'Warwickshire', 'West Mercia', 'West Midlands', 'East',
#        'Bedfordshire', 'Cambridgeshire', 'Essex', 'Hertfordshire',
#        'Norfolk', 'Suffolk', 'London',
#        'City of London / Metropolitan Police', 'South East', 'Hampshire',
#        'Kent', 'Surrey', 'Sussex', 'Thames Valley', 'South West',
#        'Avon and Somerset', 'Devon and Cornwall', 'Dorset',
#        'Gloucestershire', 'Wiltshire', 'Wales', 'Dyfed-Powys', 'Gwent',
#        'North Wales', 'South Wales'], dtype=object)

# %%
df['Geography_type'].unique() #drop
# Out:
# array(['ONS geography code'], dtype=object)

# %%
df['Geography code'].unique() #drop
# Out:
# array(['K04000001', 'E12000001', 'E23000013', 'E23000008', 'E23000007',
#        'E12000002', 'E23000006', 'E23000002', 'E23000005', 'E23000003',
#        'E23000004', 'E12000003', 'E23000012', 'E23000009', 'E23000011',
#        'E23000010', 'E12000004', 'E23000018', 'E23000021', 'E23000020',
#        'E23000022', 'E23000019', 'E12000005', 'E23000015', 'E23000017',
#        'E23000016', 'E23000014', 'E12000006', 'E23000026', 'E23000023',
#        'E23000028', 'E23000027', 'E23000024', 'E23000025', 'E12000007',
#        'E12000008', 'E23000030', 'E23000032', 'E23000031', 'E23000033',
#        'E23000029', 'E12000009', 'E23000036', 'E23000035', 'E23000039',
#        'E23000037', 'E23000038', 'W92000004', 'W15000004', 'W15000002',
#        'W15000001', 'W15000003'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['All', 'Male', 'Female', 'Male '], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['16+', '16-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75+'],
#       dtype=object)

# %%
df['Socio-economic classification'].unique()
# Out:
# array(['All', 'Managerial and professional occupations',
#        'Intermediate occupations', 'Routine and manual occupations',
#        'Never worked and long-term unemployed', 'Full time students',
#        'Not classified'], dtype=object)

# %%
df['Household income'].unique()
# Out:
# array(['All', 'Less than £10,000', '£10,000 to less than £20,000',
#        '£20,000 to less than £30,000', '£30,000 to less than £40,000',
#        '£40,000 to less than £50,000', '£50,000 or more',
#        'No income stated/Not enough information provided '], dtype=object)

# %%
df['Value'].unique()
# Out:
# array(['17.0', '25.1', '21.0', '19.8', '17.4', '13.5', '10.2', '6.0',
#        '16.7', '17.2', '16.3', '16.1', '17.6', '23.6', '11.3', '16.5',
#        '15.8', '18.2', '19.2', '15.9', '18.6', '16.9', '20.6', '?',
#        '29.0', '23.5', '20.3', '20.4', '17.1', '14.6', '15.2', '16.0',
#        '17.3', '9.9', '27.2', '13.8', '16.8', '22.1', '20.5', '18.9',
#        '12.5', '9.0', '5.9', '15.3', '15.5', '18.0', '13.6', '14.9',
#        '17.5', '18.1', '14.8', '29.1', '27.9', '22.8', '14.4', '21.9',
#        '11.6', '11.4', '13.9', '18.7', '14.7', '27.6', '10.3', '15.7',
#        '13.2', '14.0', '11.7', '13.3', '10.9', '9.2', '14.1', '16.2',
#        '13.1', '15.0', '12.7', '15.4', '14.2', '13.7', '12.2', '10.8',
#        '12.8', '14.3', '8.9', '19.9', '23.1', '11.5', '27.3', '24.5',
#        '24.4', '29.2', '25.5', '18.3', '18.4', '18.8', '10.7', '22.6',
#        '26.1', '11.2', '21.7', '5.8', '26.6', '17.7', '12.3', '12.0',
# ...

# %%
df['Value_type'].unique() #drop
# Out:
# array(['%'], dtype=object)

# %%
df['Sample size'].unique() #drop
# Out:
# array(['35371', '2790', '5254', '5826', '6087', '5689', '5296', '4429',
#        '16176', '19195', '11760', '8300', '12620', '1322', '1200', '169',
#        '4618', '7155', '5161', '3778', '2670', '5588', '6401', '1824',
#        '959', '30073', '322', '12', '1573', '120', '46', '80', '93',
#        '767', '398', '138', '352', '564', '350', '45', '88', '148', '339',
#        '236', '31980', '33350', '2409', '4785', '5436', '5645', '5336',
#        '5384', '4355', '15030', '18320', '11298', '7690', '11823', '1310',
#        '1027', '202', '3965', '6724', '4972', '3744', '2672', '5580',
#        '5688', '1649', '28476', '299', '10', '1427', '98', '90', '76',
#        '679', '388', '123', '136', '323', '529', '316', '57', '83', '151',
#        '902', '309', '234', '30212', '93852', '6167', '1837', '1991',
#        '2339', '11548', '1838', '1822', '3657', '2236', '1995', '8749',
#        '1938', '1912', '3061', '8881', '1866', '1692', '1878', '1689',
# ...

# %%
df['Standard Error'].unique() #drop
# Out:
# array(['0.199790931', '0.820736685', '0.561916822', '0.52167067',
#        '0.486138089', '0.45250823', '0.415780146', '0.356312388',
#        '0.297811508', '0.26909033', '0.348103756', '0.405835236',
#        '0.327033381', '1.046563497', '1.225378962', '2.433097301',
#        '0.545749574', '0.430977105', '0.516112217', '0.61913227',
#        '0.746810324', '0.526638956', '0.456920034', '0.912019804',
#        '1.209126606', '0.215040144', '2.25535656', '?', '0.952518087',
#        '4.140182765', '4.743250525', '4.704626098', '1.452502832',
#        '2.018208653', '3.204030638', '2.713511211', '1.912777767',
#        '1.545274508', '2.023337628', '3.184672775', '3.013270694',
#        '2.41651735', '2.242920738', '0.208937867', '0.200457491',
#        '0.845807622', '0.583099364', '0.530648107', '0.497384606',
#        '0.452841129', '0.3908573', '0.358232402', '0.303990198',
#        '0.265609166', '0.345721588', '0.409431867', '0.332577433',
# ...

# %%
df['Lower CI'].unique() #drop
# Out:
# array(['16.54', '23.16', '19.68', '18.53', '16.28', '12.4', '9.22',
#        '5.14', '16.66', '16.05', '16.39', '15.39', '15.32', '15.1',
#        '20.7', '5.55', '15.18', '14.77', '15.24', '16.11', '16.45',
#        '17.94', '14.81', '16.5', '14.02', '16.19', '15.33', '?', '15.01',
#        '19.21', '12.38', '17.92', '16.89', '15.61', '9.55', '8.18',
#        '10.69', '12.41', '12.57', '2.42', '8.91', '21.5', '8.49', '15.47',
#        '20.14', '19.08', '17.62', '11.44', '8.12', '5.1', '15.95',
#        '14.63', '15.28', '14.24', '14.69', '15.51', '16.02', '11.65',
#        '15.4', '12.59', '13.71', '16.08', '15', '16.85', '13.74', '13.65',
#        '12.14', '16.2', '18.32', '16.81', '11.49', '11.22', '16.99',
#        '4.79', '4.96', '9.37', '14.73', '10.01', '13.66', '2.45', '10.2',
#        '21.88', '9.3', '15.23', '14.47', '12.37', '14.76', '12.51',
#        '10.37', '12.69', '9.52', '10.18', '13.27', '14.32', '9.92',
# ...

# %%
df['Upper CI'].unique() #drop
# Out:
# array(['17.48329817', '27.01789164', '22.32082154', '20.98609175',
#        '18.56337501', '14.52528845', '11.17258981', '6.818724567',
#        '18.06116414', '17.31477294', '18.0320416', '17.29488373',
#        '16.85339713', '20.02666253', '26.45983403', '16.99892678',
#        '17.74910013', '16.7934704', '17.66907469', '19.02474792',
#        '19.9622769', '20.41372852', '16.96272273', '20.79490225',
#        '19.70847197', '17.19877212', '25.94298925', '?', '19.48621257',
#        '38.68856734', '34.69623188', '40.05138341', '23.72098995',
#        '25.10091868', '24.62208511', '20.94732522', '19.68318174',
#        '19.67510614', '22.09183186', '17.39681448', '23.08442515',
#        '32.87158005', '19.04336994', '17.26624957', '16.41431678',
#        '24.12136141', '21.82357833', '20.11464864', '17.95125012',
#        '13.57144701', '9.96213101', '6.7844093', '17.38216193',
#        '15.87479991', '16.90702499', '16.16512391', '16.25274801',
# ...

# %%
# Removing unnecessary variables.
df.drop(['Measure','Value_type', 'Sample size','Standard Error','Lower CI','Upper CI','Ethnicity_type','Time_type','Geography_type','Geography code'], axis= 1, inplace= True)

# %%
df = df.rename(columns={'Time': 'Year', 'Geography':'Region'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1183 entries, 0 to 1182
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Ethnicity                      1183 non-null   object
#  1   Year                           1183 non-null   object
#  2   Region                         1183 non-null   object
#  3   Gender                         1183 non-null   object
#  4   Age                            1183 non-null   object
#  5   Socio-economic classification  1183 non-null   object
#  6   Household income               1183 non-null   object
#  7   Value                          1183 non-null   object
# dtypes: object(8)
# memory usage: 74.1+ KB

# %%
# save dataset.
df.to_csv(r'//content/drive/MyDrive/cleaned_data_crime.csv', index=False)
